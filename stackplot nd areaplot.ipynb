# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
area=[2,4,3,5,1]
area1=[2,4,6,3,5]
area2=[3,2,4,6,5]
plt.stackplot(x,area,area1,area2)
plt.show()

# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
area=[2,4,3,5,1]
area1=[2,4,6,3,5]
area2=[3,2,4,6,5]
l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2,labels=l)
plt.show()

# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
area=[2,4,3,5,1]
area1=[2,4,6,3,5]
area2=[3,2,4,6,5]
l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2,labels=l)

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
area=[2,4,3,5,1]
area1=[2,4,6,3,5]
area2=[3,2,4,6,5]
l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2,labels=l,colors=["r","y","g"])

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
area=[2,4,3,5,1]
area1=[2,4,6,3,5]
area2=[3,2,4,6,5]
l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2,labels=l,colors=["r","y","g"],baseline="sym")

plt.legend(loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt 
x=[1,2,3,4,5]
area=[2,4,3,5,1]
area1=[2,4,6,3,5]
area2=[3,2,4,6,5]
l=["area","area1","area2"]
plt.stackplot(x,area,area1,area2,labels=l,colors=["r","y","g"])

plt.title("python")
plt.grid()

plt.legend(loc=2)
plt.show()
