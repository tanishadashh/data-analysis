# %%
import pandas as pd

# %%
data= pd.read_csv(r'C:\Users\tanis\Salaries.csv')
data
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_29564\1645619453.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data= pd.read_csv(r'C:\Users\tanis\Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
data.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
data = data.drop(['Id','Notes','Agency','Status'],axis=1)

# %%
data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
data.describe()
# Out:
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# 50%     71426.610000      92404.090000    2013.000000
# 75%    105839.135000     132876.450000    2014.000000
# max    567595.430000     567595.430000    2014.000000

# %%
 data.describe(include='all')
# Out:
#        EmployeeName          JobTitle   BasePay  OvertimePay  OtherPay  \
# count        148654            148654  148049.0     148654.0  148654.0
# unique       110811              2159  109900.0      66555.0   84968.0
# top       Kevin Lee  Transit Operator       0.0          0.0       0.0
# freq             13              7036     875.0      66103.0   35218.0
# mean            NaN               NaN       NaN          NaN       NaN
# std             NaN               NaN       NaN          NaN       NaN
# min             NaN               NaN       NaN          NaN       NaN
# 25%             NaN               NaN       NaN          NaN       NaN
# 50%             NaN               NaN       NaN          NaN       NaN
# 75%             NaN               NaN       NaN          NaN       NaN
# max             NaN               NaN       NaN          NaN       NaN
#
#         Benefits       TotalPay  TotalPayBenefits           Year
# ...

# %%
data['EmployeeName'].value_counts()
# Out:
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: EmployeeName, Length: 110811, dtype: int64

# %%
data['EmployeeName'].value_counts().head()
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %%
data['JobTitle'].nunique()
# Out:
# 2159

# %%
data['JobTitle'].str.contains('Captain')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
data[data['JobTitle'].str.contains('Captain')]
# Out:
#               EmployeeName                   JobTitle    BasePay OvertimePay  \
# 36167        John Goldberg                  Captain 3   104404.0         0.0
# 36180     Michael Rolovich  Captain, Fire Suppression  145659.03   125868.06
# 36184        Darryl Hunter  Captain, Fire Suppression  145659.03   115673.73
# 36186       Michael Delane  Captain, Fire Suppression  147069.71   113372.94
# 36189       Philip Stevens  Captain, Fire Suppression   124573.5    53895.92
# ...                    ...                        ...        ...         ...
# 116604   Gregory L Stewart  Captain, Fire Suppression   73355.21    18517.18
# 120867     Michael J Moran                  Captain 3     7660.0     1496.09
# 122361  Michael V Rolovich  Captain, Fire Suppression        0.0         0.0
# 126588    Stephen M Tittel                  Captain 3   68491.89         0.0
# 132232     Jeanne M Seyler  Captain, Fire Suppression   61039.43     2285.30
#
# ...

# %%
len(data[data['JobTitle'].str.contains('Captain')])
# Out:
# 411

# %%
data[data['JobTitle'].str.contains('Captain')]
# Out:
#               EmployeeName                   JobTitle    BasePay OvertimePay  \
# 36167        John Goldberg                  Captain 3   104404.0         0.0
# 36180     Michael Rolovich  Captain, Fire Suppression  145659.03   125868.06
# 36184        Darryl Hunter  Captain, Fire Suppression  145659.03   115673.73
# 36186       Michael Delane  Captain, Fire Suppression  147069.71   113372.94
# 36189       Philip Stevens  Captain, Fire Suppression   124573.5    53895.92
# ...                    ...                        ...        ...         ...
# 116604   Gregory L Stewart  Captain, Fire Suppression   73355.21    18517.18
# 120867     Michael J Moran                  Captain 3     7660.0     1496.09
# 122361  Michael V Rolovich  Captain, Fire Suppression        0.0         0.0
# 126588    Stephen M Tittel                  Captain 3   68491.89         0.0
# 132232     Jeanne M Seyler  Captain, Fire Suppression   61039.43     2285.30
#
# ...

# %%
data[data['JobTitle'].str.contains('Captain')].count()
# Out:
# EmployeeName        411
# JobTitle            411
# BasePay             410
# OvertimePay         411
# OtherPay            411
# Benefits            411
# TotalPay            411
# TotalPayBenefits    411
# Year                411
# dtype: int64

# %%
data[data['JobTitle'].str.contains('fire',case=False)]['EmployeeName']
# Out:
# 4            PATRICK GARDNER
# 6                  ALSON LEE
# 8             MICHAEL MORRIS
# 9         JOANNE HAYES-WHITE
# 10             ARTHUR KENNEY
#                  ...
# 145956      Kenneth C Farris
# 147556         Edward A Dunn
# 148021        Kari A Johnson
# 148209          Sheryl K Lee
# 148554       Lawrence F Gatt
# Name: EmployeeName, Length: 5879, dtype: object

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
import numpy as np 
data['EmployeeName']=data['EmployeeName'].replace('Not provided',np.nan)

# %%
data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
data[data.drop(data.isnull().sum(axis=1))]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data[data.drop(data.isnull().sum(axis=1))]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3794, in DataFrame.__getitem__(self, key)
#    3792 # Do we have a (boolean) DataFrame?
#    3793 if isinstance(key, DataFrame):
# -> 3794     return self.where(key)
#    3796 # Do we have a (boolean) 1d indexer?
#    3797 if com.is_bool_indexer(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year'],
#       dtype='object')

# %%
data[data['EmployeeName']=='ALBERT PARDINI']['JobTitle']
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
data[data['EmployeeName']=='ALBERT PARDINI']['TotalPayBenefits']
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
if data['']

# %%
data['BasePay'] = pd.data['BasePay']
# Out:
# 0            167411.18
# 1            155966.02
# 2            212739.13
# 3              77916.0
# 4             134401.6
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: BasePay, Length: 148654, dtype: object

# %%
type(data['BasePay'][0])==str
# Out:
# False

# %%
type(data['BasePay'][148651])==str
# Out:
# True

# %%
data['ind'] = data.index

# %%
data
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                    Not provided
# 148651                NaN                                    Not provided
# 148652                NaN                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %%
def func(dd):
    if type(data['BasePay'][dd])==str:
        data['BasePay'][dd] = 0
    else:
        pass

# %%
data['NBase'] = data['ind'].apply(lambda x: func(x))
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_29564\2342705366.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['BasePay'][dd] = 0

# %%
data['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3           77916.0
# 4          134401.6
#             ...
# 148649            0
# 148650            0
# 148651            0
# 148652            0
# 148653            0
# Name: BasePay, Length: 148654, dtype: object

# %%
data['BasePay'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 148654 entries, 0 to 148653
# Series name: BasePay
# Non-Null Count   Dtype
# --------------   -----
# 148049 non-null  object
# dtypes: object(1)
# memory usage: 1.1+ MB

# %%
data[data['BasePay']==data['BasePay'].max()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data[data['BasePay']==data['BasePay'].max()]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11941, in NDFrame._add_numeric_operations.<locals>.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11921 @doc(
#   11922     _num_doc,
#   11923     desc="Return the maximum of the values over the requested axis.\n\n"
#    (...)
#   11939     **kwargs,
#   11940 ):
# > 11941     return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11383, in NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11375 def max(
#   11376     self,
#   11377     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11381     **kwargs,
#   11382 ):
# > 11383     return self._stat_function(
# ...

# %%
data.groupby('Year').mean()['BasePay']
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_29564\3282093210.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('Year').mean()['BasePay']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
data.columns
# Out:
# Index(['EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'ind', 'NBase'],
#       dtype='object')

# %%
data['JobTitle'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object>
