# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
topics_url = r'https://github.com/topics'
response =requests.get(topics_url)

# %%
response.status_code
len(response.text)
# Out:
# 165688

# %%
page_content= response.text

# %%
page_content[:10000]
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"  data-a11y-animated-images="system" data-a11y-link-underlines="false">\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-a09cef873428.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-5d486a4ede8e.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" 
# ...

# %%
doc= BeautifulSoup(page_content, 'html.parser') 
doc
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-a11y-link-underlines="false" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
selection_class= 'f3 lh-condensed mb-0 mt-1 Link--primary'
topic_title_tags= doc.find_all('p', {'class': selection_class})
len(topic_title_tags)
# Out:
# 30

# %%
topic_title_tags
# Out:
# [<p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amp</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Angular</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ansible</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">API</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Arduino</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">ASP.NET</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Atom</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Awesome Lists</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amazon Web Services</p>,
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Azure</p>,
# ...

# %%
topic_titles = [ ]

for tag in topic_title_tags:
    topic_titles.append(tag.text)
print(topic_titles)
# Out:
# ['3D', 'Ajax', 'Algorithm', 'Amp', 'Android', 'Angular', 'Ansible', 'API', 'Arduino', 'ASP.NET', 'Atom', 'Awesome Lists', 'Amazon Web Services', 'Azure', 'Babel', 'Bash', 'Bitcoin', 'Bootstrap', 'Bot', 'C', 'Chrome', 'Chrome extension', 'Command line interface', 'Clojure', 'Code quality', 'Code review', 'Compiler', 'Continuous integration', 'COVID-19', 'C++']

# %%
desc_selector ='f5 color-fg-muted mb-0 mt-1'
          
topic_desc_tags =doc.find_all('p', {'class': desc_selector})

# %%
topic_desc_tags [:]
# Out:
# [<p class="f5 color-fg-muted mb-0 mt-1">
#            3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ajax is a technique for creating interactive web applications.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Algorithms are self-contained sequences that carry out a variety of tasks.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Amp is a non-blocking concurrency library for PHP.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Android is an operating system built by Google designed for mobile devices.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Angular is an open source web application platform.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ansible is a simple and powerful automation engine.
#          </p>,
# ...

# %%
topic_descs = []

for tag in topic_desc_tags:
    topic_descs.append(tag.text.strip())
print(topic_descs[:])
# Out:
# ['3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.', 'Ajax is a technique for creating interactive web applications.', 'Algorithms are self-contained sequences that carry out a variety of tasks.', 'Amp is a non-blocking concurrency library for PHP.', 'Android is an operating system built by Google designed for mobile devices.', 'Angular is an open source web application platform.', 'Ansible is a simple and powerful automation engine.', 'An API (Application Programming Interface) is a collection of protocols and subroutines for building software.', 'Arduino is an open source platform for building electronic devices.', 'ASP.NET is a web framework for building modern web apps and services.', 'Atom is a open source text editor built with web technologies.', 'An awesome list is a list of awesome things curated by the community.', 'Amazon Web Services provides on-demand cloud computing platforms on a subscription basis.', 'Azure is a cloud 
# ...

# %%
topic_title_tags4 = topic_title_tags[4]

# %%
topic_title_tags4
# Out:
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>

# %%
topic_title_tags4.parent
# Out:
# <a class="no-underline flex-1 d-flex flex-column" href="/topics/android">
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>
# <p class="f5 color-fg-muted mb-0 mt-1">
#           Android is an operating system built by Google designed for mobile devices.
#         </p>
# </a>

# %%
link_selector ='no-underline flex-1 d-flex flex-column'
topic_link_tags = doc.find_all('a', {'class': link_selector})

# %%
topic_link_tags
# Out:
# [<a class="no-underline flex-1 d-flex flex-column" href="/topics/3d">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/ajax">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ajax is a technique for creating interactive web applications.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/algorithm">
#  <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Algorithms are self-contained sequences that carry out a variety of tasks.
#          </p>
#  </a>,
#  <a class="no-underline flex-1 d-flex flex-column" href="/topics/amphp">
# ...

# %%
len(topic_link_tags)
# Out:
# 30

# %%
topic_link_tags[4]['href']
# Out:
# '/topics/android'

# %%
topic4_url= 'https://github.com' + topic_link_tags[4]['href']
print(topic4_url)
# Out:
# https://github.com/topics/android

# %%
topic_urls = []
base_url = 'https://github.com'

for url in topic_link_tags:
    topic_urls.append(base_url + url['href'])
print(topic_urls[:10])
# Out:
# ['https://github.com/topics/3d', 'https://github.com/topics/ajax', 'https://github.com/topics/algorithm', 'https://github.com/topics/amphp', 'https://github.com/topics/android', 'https://github.com/topics/angular', 'https://github.com/topics/ansible', 'https://github.com/topics/api', 'https://github.com/topics/arduino', 'https://github.com/topics/aspnet']

# %%
import pandas as pd

# %%
topics_dict = {
    'title': topic_titles,
    'description': topic_descs,
    'urls': topic_urls
}

# %%
topic_df = pd.DataFrame(topics_dict)

# %%
topic_df.head(10)
# Out:
#        title                                        description  \
# 0         3D  3D refers to the use of three-dimensional grap...
# 1       Ajax  Ajax is a technique for creating interactive w...
# 2  Algorithm  Algorithms are self-contained sequences that c...
# 3        Amp  Amp is a non-blocking concurrency library for ...
# 4    Android  Android is an operating system built by Google...
# 5    Angular  Angular is an open source web application plat...
# 6    Ansible  Ansible is a simple and powerful automation en...
# 7        API  An API (Application Programming Interface) is ...
# 8    Arduino  Arduino is an open source platform for buildin...
# 9    ASP.NET  ASP.NET is a web framework for building modern...
#
#                                   urls
# 0         https://github.com/topics/3d
# 1       https://github.com/topics/ajax
# 2  https://github.com/topics/algorithm
# 3      https://github.com/topics/amphp
# 4    https://github.com/topics/android
# ...

# %%
topic_page_url = topic_urls[4]
topic_page_url
# Out:
# 'https://github.com/topics/android'

# %%
response= requests.get(topic_page_url)

# %%
response
# Out:
# <Response [200]>

# %%
len(response.text)
# Out:
# 430954

# %%
topic_doc = BeautifulSoup(response.text,'html.parser')

# %%
topic_doc
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-a11y-link-underlines="false" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
h3_selection_class = 'f3 color-fg-muted text-normal lh-condensed'
repo_tags= topic_doc.find_all('h3',{'class':h3_selection_class })

# %%
repo_tags
# Out:
# [<h3 class="f3 color-fg-muted text-normal lh-condensed">
#  <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":14101776,"originating_url":"https://github.com/topics/android","user_id":null}}' data-hydro-click-hmac="e1f4fa355a7cd5754931010d5599adddfd57bb95cb99230a4ef242d449538b08" data-turbo="false" data-view-component="true" href="/flutter">
#              flutter
#  </a>          /
# ...

# %%
len(repo_tags)
# Out:
# 20

# %%
repo_tags[4]
# Out:
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":18143746,"originating_url":"https://github.com/topics/android","user_id":null}}' data-hydro-click-hmac="0ea2e43fe2b304873417485bbd1175e847ea7b24191457e3a6307a16fe60a550" data-turbo="false" data-view-component="true" href="/Hack-with-Github">
#             Hack-with-Github
# </a>          /
# ...

# %%
repo_tags[4].text
# Out:
# '\n\n            Hack-with-Github\n          /\n          \n            Awesome-Hacking\n '

# %%
a_tags = repo_tags[4].find_all('a')

# %%
a_tags
# Out:
# [<a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":18143746,"originating_url":"https://github.com/topics/android","user_id":null}}' data-hydro-click-hmac="0ea2e43fe2b304873417485bbd1175e847ea7b24191457e3a6307a16fe60a550" data-turbo="false" data-view-component="true" href="/Hack-with-Github">
#              Hack-with-Github
#  </a>,
# ...

# %%
a_tags[0].text.strip()
# Out:
# 'Hack-with-Github'

# %%
a_tags[1].text.strip()
# Out:
# 'Awesome-Hacking'

# %%
a_tags[1]['href']
# Out:
# '/Hack-with-Github/Awesome-Hacking'

# %%
base_url+a_tags[0]['href']
# Out:
# 'https://github.com/Hack-with-Github'

# %%
star_tags = topic_doc.find_all('span', {'class':'Counter js-social-count'})
star_tags
# Out:
# [<span aria-label="156915 users starred this repository" class="Counter js-social-count" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="156,915">157k</span>,
#  <span aria-label="112145 users starred this repository" class="Counter js-social-count" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="112,145">112k</span>,
#  <span aria-label="105139 users starred this repository" class="Counter js-social-count" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="105,139">105k</span>,
# ...

# %%
star_tags[4].text.strip()
# Out:
# '69.4k'

# %%
def parse_star_count(stars_str):
    stars_str = stars_str.strip()
    if stars_str[-1] == 'k':
        return int(float(stars_str[:-1])*1000)
    return int(stars_str)

# %%
parse_star_count(star_tags[4].text.strip())
# Out:
# 69400

# %%
def get_repo_info(h3_tag, star_tag):
    print("Function get_repo_info started")
    # returns all the required info about repository
    a_tags = h3_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, repo_url, stars
    print(username, repo_name, repo_url, stars)
print("get_repo_info function completed")
# Out:
# get_repo_info function completed

# %%
repo_tags[4]
# Out:
# <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":18143746,"originating_url":"https://github.com/topics/android","user_id":null}}' data-hydro-click-hmac="0ea2e43fe2b304873417485bbd1175e847ea7b24191457e3a6307a16fe60a550" data-turbo="false" data-view-component="true" href="/Hack-with-Github">
#             Hack-with-Github
# </a>          /
# ...

# %%
star_tags[4]
# Out:
# <span aria-label="69390 users starred this repository" class="Counter js-social-count" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-turbo-replace="true" data-view-component="true" id="repo-stars-counter-star" title="69,390">69.4k</span>

# %%
get_repo_info(repo_tags[4], star_tags[4])
# Out:
# Function get_repo_info started
# ('Hack-with-Github',
#  'Awesome-Hacking',
#  'https://github.com/Hack-with-Github/Awesome-Hacking',
#  69400)

# %%
topic_repos_dict ={
    'username':[],
    'repo_name':[],
    'stars':[],
    'repo_url':[]
}

for i in range(len(repo_tags)):
    repo_info= get_repo_info(repo_tags[i] ,star_tags[i])
    topic_repos_dict['username'].append(repo_info[0])
    topic_repos_dict['repo_name'].append(repo_info[1])
    topic_repos_dict['stars'].append(repo_info[3])
    topic_repos_dict['repo_url'].append(repo_info[2])
# Out:
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started
# Function get_repo_info started

# %%
topic_repos_df =pd.DataFrame(topic_repos_dict)
topic_repos_df
# Out:
#             username                     repo_name   stars  \
# 0            flutter                       flutter  157000
# 1           facebook                  react-native  112000
# 2          justjavac  free-programming-books-zh_CN  105000
# 3         Genymobile                        scrcpy   91500
# 4   Hack-with-Github               Awesome-Hacking   69400
# 5             google         material-design-icons   48700
# 6             Solido               awesome-flutter   48600
# 7           wasabeef            awesome-android-ui   47400
# 8             square                        okhttp   44500
# 9            android          architecture-samples   43200
# 10            square                      retrofit   42000
# 11         laurent22                        joplin   38700
# 12          dcloudio                       uni-app   38600
# 13          fastlane                      fastlane   37600
# 14           PhilJay                MPAndroidChart   36800
# ...

# %%
def get_topic_page(topic_url):
    print("Function get_topic_page started")
    # Get the topic url
    topics_url = "https://github.com/topics"
    response = requests.get(topics_url)
    if response.status_code != 200:
        raise Exception("Failed to load Page {}".format(topic_url))
    doc = BeautifulSoup(response.text, 'html.parser')
    return doc
    print(doc)
print("get_topic_page function completed")
# Out:
# get_topic_page function completed

# %%
topic_urls[4]
# Out:
# 'https://github.com/topics/android'

# %%
pwd
# Out:
# 'C:\\Users\\tanis'

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_topic_titles(doc):
    print("Function get_topic_titles started")
    selection_class= 'f3 lh-condensed mb-0 mt-1 Link--primary'
    topic_title_tags = doc.find_all('p', {'class':selection_class})
    topic_titles = []
    for tag in topic_title_tags:
        topic_titles.append(tag.text)
    return topic_titles
print("get_topic_titles function completed")
# Out:
# get_topic_titles function completed

# %%
   topic_titles
# Out:
# ['3D',
#  'Ajax',
#  'Algorithm',
#  'Amp',
#  'Android',
#  'Angular',
#  'Ansible',
#  'API',
#  'Arduino',
#  'ASP.NET',
#  'Atom',
#  'Awesome Lists',
#  'Amazon Web Services',
#  'Azure',
#  'Babel',
#  'Bash',
#  'Bitcoin',
#  'Bootstrap',
#  'Bot',
#  'C',
#  'Chrome',
#  'Chrome extension',
#  'Command line interface',
#  'Clojure',
#  'Code quality',
#  'Code review',
#  'Compiler',
#  'Continuous integration',
#  'COVID-19',
#  'C++']

# %%
def get_topic_descs(doc):
    print("Function get_topic_descs started")
    desc_selector = 'f5 color-fg-muted mb-0 mt-1'
    topic_desc_tags= doc.find_all('p', {'class':desc_selector})
    topic_descs =[]
    for tag in topic_desc_tags:
        topic_descs.append(tag.text.strip())
    return topic_descs
    print(topic_descs)
print("get_topic_descs function completed")
# Out:
# get_topic_descs function completed

# %%
  topic_descs
# Out:
# ['3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.',
#  'Ajax is a technique for creating interactive web applications.',
#  'Algorithms are self-contained sequences that carry out a variety of tasks.',
#  'Amp is a non-blocking concurrency library for PHP.',
#  'Android is an operating system built by Google designed for mobile devices.',
#  'Angular is an open source web application platform.',
#  'Ansible is a simple and powerful automation engine.',
#  'An API (Application Programming Interface) is a collection of protocols and subroutines for building software.',
#  'Arduino is an open source platform for building electronic devices.',
#  'ASP.NET is a web framework for building modern web apps and services.',
#  'Atom is a open source text editor built with web technologies.',
#  'An awesome list is a list of awesome things curated by the community.',
# ...

# %%
def get_topic_urls(doc):
    print("Function get_topic_urls started")
    topic_link_tags = doc.find_all('a', {'class':'"no-underline flex-grow-0"'})
    topic_urls =[]
    base_url = 'https://github.com'
    for tag in topic_link_tags:
        topic_urls.append(base_url + tag['href'])
    return topic_urls
    print(topic_urls)
print("get_topic_urls function completed")
# Out:
# get_topic_urls function completed

# %%
  topic_urls
# Out:
# ['https://github.com/topics/3d',
#  'https://github.com/topics/ajax',
#  'https://github.com/topics/algorithm',
#  'https://github.com/topics/amphp',
#  'https://github.com/topics/android',
#  'https://github.com/topics/angular',
#  'https://github.com/topics/ansible',
#  'https://github.com/topics/api',
#  'https://github.com/topics/arduino',
#  'https://github.com/topics/aspnet',
#  'https://github.com/topics/atom',
#  'https://github.com/topics/awesome',
#  'https://github.com/topics/aws',
#  'https://github.com/topics/azure',
#  'https://github.com/topics/babel',
#  'https://github.com/topics/bash',
#  'https://github.com/topics/bitcoin',
#  'https://github.com/topics/bootstrap',
#  'https://github.com/topics/bot',
#  'https://github.com/topics/c',
#  'https://github.com/topics/chrome',
#  'https://github.com/topics/chrome-extension',
#  'https://github.com/topics/cli',
#  'https://github.com/topics/clojure',
#  'https://github.com/topics/code-quality',
# ...

# %%
import pandas as pd
def scrape_topics():
    print("Function scrape_topics started")
    topics_url = r'https://github.com/topics'
    response =requests.get(topics_url)
    if response.status_code != 200:
        raise Exception('Failed to load page {}'.format(topic_url))
    doc = BeautifulSoup(response.text, 'html.parser')
    topics_dict = {
        'title': get_topic_titles(doc),
        'description': get_topic_descs(doc),
        'url': get_topic_urls(doc)
    }
    return pd.DataFrame(topics_dict)
    print(pd.DataFrame(topics_dict))
print("scrape_topics function completed")
# Out:
# scrape_topics function completed

# %%
  topics_dict
# Out:
# {'title': ['3D',
#   'Ajax',
#   'Algorithm',
#   'Amp',
#   'Android',
#   'Angular',
#   'Ansible',
#   'API',
#   'Arduino',
#   'ASP.NET',
#   'Atom',
#   'Awesome Lists',
#   'Amazon Web Services',
#   'Azure',
#   'Babel',
#   'Bash',
#   'Bitcoin',
#   'Bootstrap',
#   'Bot',
#   'C',
#   'Chrome',
#   'Chrome extension',
#   'Command line interface',
#   'Clojure',
#   'Code quality',
#   'Code review',
#   'Compiler',
#   'Continuous integration',
#   'COVID-19',
#   'C++'],
#  'description': ['3D refers to the use of three-dimensional graphics, modeling, and animation in various industries.',
#   'Ajax is a technique for creating interactive web applications.',
#   'Algorithms are self-contained sequences that carry out a variety of tasks.',
#   'Amp is a non-blocking concurrency library for PHP.',
#   'Android is an operating system built by Google designed for mobile devices.',
#   'Angular is an open source web application platform.',
# ...

# %%
def get_topic_page(topic_url):
    print("Function get_topic_page started")
    #download the page
    response = requests.get(topic_url)
    #check successful response
    if response.status_code !=200:
        raise Exception('Failed to load page {}'.format(topic_url))
    #Parse using Beautiful Soup
    topic_doc = BeautifulSoup(response.text, 'html.parser')
    return topic_doc
print("get_topic_page function completed")
# Out:
# get_topic_page function completed

# %%
  topic_doc
# Out:
# <!DOCTYPE html>
#
# <html data-a11y-animated-images="system" data-a11y-link-underlines="false" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
# <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
# ...

# %%
def get_repo_info(h3_tag, star_tag):
    print("Function get_repo_info started")
   
    a_tags = h3_tag.find_all('a')
    username = a_tags[0].text.strip()
    repo_name = a_tags[1].text.strip()
    repo_url = base_url + a_tags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    return username, repo_name, repo_url, stars
print("get_repo_info function completed")
# Out:
# get_repo_info function completed

# %%
 a_tags
# Out:
# [<a class="Link" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":18143746,"originating_url":"https://github.com/topics/android","user_id":null}}' data-hydro-click-hmac="0ea2e43fe2b304873417485bbd1175e847ea7b24191457e3a6307a16fe60a550" data-turbo="false" data-view-component="true" href="/Hack-with-Github">
#              Hack-with-Github
#  </a>,
# ...

# %%
get_repo_info
# Out:
# <function __main__.get_repo_info(h3_tag, star_tag)>

# %%
def get_topic_repos(topic_doc):
    print("Function get_topic_repos started")

    h1_selection_class ='f3 color-text-secondry text-normal lh-condensed'
    repo_tags = topic_doc.find_all('h1', {'class':h1_selection_class})
 
    star_tags = topic_doc.find_all('a', {'class':'social-count float-none'})
    topic_repo_dict = {'username':[], 'repo_name':[], 'stars':[], 'repo_url':[]}

    for i in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[i], star_tags[i])
        topic_repos_dict['username'].append(repo_info[0])
        topic_repos_dict['repo_name'].append(repo_info[1])
        topic_repos_dict['stars'].append(repo_info[3])
        topic_repos_dict['repo_url'].append(repo_info[2])
    return pd.DataFrame(topic_repos_dict)
print("get_topic_repos function completed")
# Out:
# get_topic_repos function completed

# %%
 topic_repos_dict
# Out:
# {'username': ['flutter',
#   'facebook',
#   'justjavac',
#   'Genymobile',
#   'Hack-with-Github',
#   'google',
#   'Solido',
#   'wasabeef',
#   'square',
#   'android',
#   'square',
#   'laurent22',
#   'dcloudio',
#   'fastlane',
#   'PhilJay',
#   'skylot',
#   'airbnb',
#   'shadowsocks',
#   'bumptech',
#   'appwrite'],
#  'repo_name': ['flutter',
#   'react-native',
#   'free-programming-books-zh_CN',
#   'scrcpy',
#   'Awesome-Hacking',
#   'material-design-icons',
#   'awesome-flutter',
#   'awesome-android-ui',
#   'okhttp',
#   'architecture-samples',
#   'retrofit',
#   'joplin',
#   'uni-app',
#   'fastlane',
#   'MPAndroidChart',
#   'jadx',
#   'lottie-android',
#   'shadowsocks-android',
#   'glide',
#   'appwrite'],
#  'stars': [157000,
#   112000,
#   105000,
#   91500,
#   69400,
#   48700,
#   48600,
#   47400,
#   44500,
#   43200,
#   42000,
#   38700,
#   38600,
#   37600,
#   36800,
#   36300,
#   34200,
#   34000,
#   33900,
#   33200],
# ...

# %%
def scrape_topic(topic_url, path):
    print("Function scrape_topic started")
    if os.path.exists(path):
        print("The file {} already exists. Skipping...".format(path))
        return
    topic_df = get_topic_repos(get_topic_page(topic_url))
#     topic_df.to_csv(path, index=None)
    print(topic_df)
print("scrape_topic function completed")
# Out:
# scrape_topic function completed

# %%
topic_df
# Out:
#                      title                                        description  \
# 0                       3D  3D refers to the use of three-dimensional grap...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source platform for buildin...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# ...

# %%
import os
import pandas as pd

def scrape_topic_repos():
    print("Scraping list of topics")
    topics_df = scrape_topics()
    
    os.makedirs('data', exist_ok=True)
    
    # Create an empty DataFrame to store the data
    final_df = pd.DataFrame()

    for index, row in topics_df.iterrows():
        print("scraping top repositories for '{}'".format(row['title']))
        
        # Assuming scrape_topic() returns a DataFrame with the scraped data
        scraped_data = scrape_topic(row['url'])
        
        # Add a column to store the topic title in the scraped data
        scraped_data['topic'] = row['title']

        # Append the scraped data to the final DataFrame
        final_df = final_df.append(scraped_data, ignore_index=True)
            
        if 
            len(titles) != len(descriptions)
        or len(titles) != len(urls):
        raise ValueError("All arrays must be of the same length")

    # Write the final DataFrame to a single CSV file
    final_df.to_csv('data/final_data.csv', index=False)
# Out:
#   Cell In[103], line 25
#     if
#        ^
# SyntaxError: invalid syntax

# %%
scrape_topic_repos()
# Out:
# Scraping list of topics
# Function scrape_topics started
# Function get_topic_titles started
# Function get_topic_descs started
# Function get_topic_urls started
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 scrape_topic_repos()
#
# Cell In[90], line 6, in scrape_topic_repos()
#       4 def scrape_topic_repos():
#       5     print("Scraping list of topics")
# ----> 6     topics_df = scrape_topics()
#       8     os.makedirs('data', exist_ok=True)
#      10     # Create an empty DataFrame to store the data
#
# Cell In[72], line 14, in scrape_topics()
#       8 doc = BeautifulSoup(response.text, 'html.parser')
#       9 topics_dict = {
#      10     'title': get_topic_titles(doc),
#      11     'description': get_topic_descs(doc),
#      12     'url': get_topic_urls(doc)
#      13 }
# ---> 14 return pd.DataFrame(topics_dict)
# ...

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# Define functions to scrape data (you might have these functions in your code)
def get_topic_titles(doc):
    # Implement your logic to extract titles
    pass

def get_topic_descs(doc):
    # Implement your logic to extract descriptions
    pass

def get_topic_urls(doc):
    # Implement your logic to extract URLs
    pass

def scrape_topics():
    url = "https://example.com"  # Replace with the actual URL
    response = requests.get(url)
    doc = BeautifulSoup(response.text, 'html.parser')
    
    # Get the data using your scraping functions
    titles = get_topic_titles(doc)
    descriptions = get_topic_descs(doc)
    urls = get_topic_urls(doc)
    
    # Check if all lists have the same length
    if len(titles) != len(descriptions) or len(titles) != len(urls):
        raise ValueError("All arrays must be of the same length")
    
    # Create a dictionary with the data
    topics_dict = {
        'title': titles,
        'description': descriptions,
        'url': urls
    }
    
    # Create a DataFrame from the dictionary
    topics_df = pd.DataFrame(topics_dict)
    
    return topics_df

# Call the scrape_topics() function to get the DataFrame
try:
    topics_df = scrape_topics()
except ValueError as e:
    print(e)  # Handle the error appropriately

# Now you have a DataFrame containing the scraped data
print(topics_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 46
#      44 # Call the scrape_topics() function to get the DataFrame
#      45 try:
# ---> 46     topics_df = scrape_topics()
#      47 except ValueError as e:
#      48     print(e)  # Handle the error appropriately
#
# Cell In[92], line 29, in scrape_topics()
#      26 urls = get_topic_urls(doc)
#      28 # Check if all lists have the same length
# ---> 29 if len(titles) != len(descriptions) or len(titles) != len(urls):
#      30     raise ValueError("All arrays must be of the same length")
#      32 # Create a dictionary with the data
#
# TypeError: object of type 'NoneType' has no len()

# %%
get_topic_titles(doc)

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

def get_topic_titles(doc):
    print("Function get_topic_titles started")
    selection_class= 'f3 lh-condensed mb-0 mt-1 Link--primary'
    topic_title_tags = doc.find_all('p', {'class':selection_class})
    topic_titles = []
    for tag in topic_title_tags:
        topic_titles.append(tag.text)
    return topic_titles

     
    
    # Your code to extract topic titles from the BeautifulSoup document
    pass

def get_topic_descs(doc):
    # Your code to extract topic descriptions from the BeautifulSoup document
    pass

def get_topic_urls(doc):
    # Your code to extract topic URLs from the BeautifulSoup document
    pass

def scrape_topics():
    url = r'https://github.com/topics'  # Replace with your actual URL
    response = requests.get(url)
    doc = BeautifulSoup(response.text, 'html.parser')
    
    topics_dict = {
        'title': get_topic_titles(doc),
        'description': get_topic_descs(doc),
        'url': get_topic_urls(doc)
    }
    index = range(0,len(get_topic_titles))
    return pd.DataFrame(topics_dict,index = index)

def scrape_topic_repos():
    print("Scraping list of topics")
    topics_df = scrape_topics()
    
    os.makedirs('data', exist_ok=True)
    
    # Create an empty DataFrame to store the data
    data_df = pd.DataFrame(columns=['topic_title', 'topic_description', 'topic_url'])
       
    
    # Populate data_df with your scraped data
    
    # Save the DataFrame to a CSV file
    data_df.to_csv('data/topics_data.csv', index=False)
    final_df = final_df.append(scraped_data, ignore_index=True)
     

# Call your function to start the scraping process
scrape_topic_repos()
# Out:
# Scraping list of topics
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 50
#      46     final_df = final_df.append(scraped_data, ignore_index=True)
#      49 # Call your function to start the scraping process
# ---> 50 scrape_topic_repos()
#
# Cell In[117], line 34, in scrape_topic_repos()
#      32 def scrape_topic_repos():
#      33     print("Scraping list of topics")
# ---> 34     topics_df = scrape_topics()
#      36     os.makedirs('data', exist_ok=True)
#      38     # Create an empty DataFrame to store the data
#
# Cell In[117], line 29, in scrape_topics()
#      22 doc = BeautifulSoup(response.text, 'html.parser')
#      24 topics_dict = {
#      25     'title': get_topic_titles(doc),
#      26     'description': get_topic_descs(doc),
#      27     'url': get_topic_urls(doc)
#      28 }
# ---> 29 index = range(0,len(get_topic_titles))
# ...
